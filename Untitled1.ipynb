# %%
var = [10,20,30]
output1 = sum(var)

print('the sum is ' + str(output1) )
# Out:
# the sum is 60

# %%
import numpy as np
int n,m
arr1=np.array(n)
arr2=np.array(m)
n=m
output_array=arr1+arr2
print(output_array)
# Out:
#   File "<ipython-input-4-9eaab3a3cb36>", line 2
#     int n,m
#         ^
# SyntaxError: invalid syntax

# %%
#exe
sum(var)/len(var)
# Out:
# 20.0

# %%
import numpy as np

numbers = [1,2,3,4,5]

np.mean(numbers)
# Out:
# 3.0

# %%
np.linspace(1,5,7)
# Out:
# array([1.        , 1.66666667, 2.33333333, 3.        , 3.66666667,
#        4.33333333, 5.        ])

# %%
numbers_np=np.array(numbers)
numbers_np.max()
# Out:
# 5

# %%
#from numpy import mean

# %%
# in-place
#out-of-place / not in-place operations

n = [4,3,5,2,6,1,7]
nn = np.array(n)

print(nn)
nn.sort()
print(nn)
# Out:
# [4 3 5 2 6 1 7]
# [1 2 3 4 5 6 7]

# %%
n = [4,3,5,2,6,1,7]
nn = np.array(n)

print(nn)
nns=np.sort(nn)
print(nns)
# Out:
# [4 3 5 2 6 1 7]
# [1 2 3 4 5 6 7]

# %%
 import numpy as np
 import pandas as pd

 np.random.randn(3,3 )
# Out:
# array([[ 1.96590973, -1.11763016,  0.55727269],
#        [-1.70321245, -1.69911364, -1.50826739],
#        [-1.07539455, -0.26311994,  1.29820984]])

# %%
import numpy as np
import pandas as pd
#create random data
var1= np.random.randn(100)*5+ 20
var2=np.random.randn(100)>0
#variable labels
labels = ['Temp (C)','Ice cream']
#put them together into a dictionary
D = {labels[0]:var1, labels[1]:var2}

#import the dictionary into a pandas dataframe
df=pd.DataFrame(data=D)
df
# Out:
#      Temp (C)  Ice cream
# 0   13.281018       True
# 1   22.063359      False
# 2   29.395985       True
# 3   21.226714      False
# 4   19.740063      False
# ..        ...        ...
# 95  13.114266       True
# 96  28.594105       True
# 97  16.471259       True
# 98  23.399664       True
# 99  27.985786      False
#
# [100 rows x 2 columns]

# %%
# prompt: Using dataframe df: create a pandas dataframe with integers going from 0 to 10,their square, and their log

import numpy as np
import pandas as pd
df = pd.DataFrame({
    'x': range(11),
    'x^2': [x**2 for x in range(11)],
    'log(x)': [np.log(x) for x in range(1, 11)]
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-a10569a28dd1> in <cell line: 5>()
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 df = pd.DataFrame({
#       6     'x': range(11),
#       7     'x^2': [x**2 for x in range(11)],
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     707         elif isinstance(data, dict):
#     708             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710         elif isinstance(data, ma.MaskedArray):
#     711             from numpy.ma import mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
nums = np.array(range (11))

df=pd.DataFrame({'nums':nums,'square':nums**2, 'log':np.log(nums)})
df
# Out:
# <ipython-input-35-624485757081>:3: RuntimeWarning: divide by zero encountered in log
#   df=pd.DataFrame({'nums':nums,'square':nums**2, 'log':np.log(nums)})
#     nums  square       log
# 0      0       0      -inf
# 1      1       1  0.000000
# 2      2       4  0.693147
# 3      3       9  1.098612
# 4      4      16  1.386294
# 5      5      25  1.609438
# 6      6      36  1.791759
# 7      7      49  1.945910
# 8      8      64  2.079442
# 9      9      81  2.197225
# 10    10     100  2.302585

# %%
#help

sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-cdc7f52b03b8> in <cell line: 3>()
#       1 #help
#       2
# ----> 3 sum()
#
# TypeError: sum() takes at least 1 positional argument (0 given)
